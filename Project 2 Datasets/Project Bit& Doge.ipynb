# %%
import os
import csv
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
crypto = "Crypto_Fund_List without emails.csv"

# %%
crypto_df = pd.read_csv(crypto)
crypto_df.head()
# Out:
#           Unnamed: 0                        Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          Firm Name                           Address  Address 2       City
# 1      1confirmation               459 Hamilton Avenue          0  Palo Alto
# 2     360 Blockchain   Suite 734, 1055 Dunsmuir Street          0  Vancouver
# 3                3iQ  4800-1 King Street West, Box 160          0    Toronto
# 4  8 Decimal Capital              2140 Columbia Street          0  Palo Alto
#
#        Unnamed: 4 Unnamed: 5     Unnamed: 6  \
# 0  State/Province        Zip        Country
# 1              CA      94123  United States
# 2              BC    V7X 1B1         Canada
# 3              ON    M5H 1A1         Canada
# 4              CA      94306  United States
#
#                                           Unnamed: 7 Unnamed: 8    Unnamed: 9  \
# 0                                                Map       Code         Phone
# 1  http://maps.google.com/maps?f=q&hl=en&geocode=...          1  650 838 4316
# 2  http://maps.google.com/maps?f=q&hl=en&geocode=...          1  778 806 5150
# 3  http://maps.google.com/maps?f=q&hl=en&geocode=...          1  416 639 2130
# 4  http://maps.google.com/maps?f=q&hl=en&geocode=...          1  650 785 2534
#
#    ...      Unnamed: 37   Unnamed: 38    Unnamed: 39  \
# 0  ...  SEC Registered?  # of Clients  # of Accounts
# 1  ...               No           NaN            NaN
# 2  ...               No           NaN            NaN
# 3  ...               No           NaN            NaN
# 4  ...               No           NaN            NaN
#
#                           Unnamed: 40    Unnamed: 41    Unnamed: 42  \
# 0  Change in # of Accounts % (12 mo.)  Investments 1  Investments 2
# 1                                 NaN           dyDx       Basecoin
# 2                                 NaN       Arcology   SV Cryptolab
# 3                                 NaN       Ethereum        Bitcoin
# 4                                 NaN       Bluzelle           0.0%
#
#      Unnamed: 43                   Unnamed: 44    Unnamed: 45  \
# 0  Investments 3                 Investments 4  Investments 5
# 1       MakerDao                          0.0%           0.0%
# 2      Pressland  ePIC Blockchain Technologies           0.0%
# 3       Litecoin                          0.0%           0.0%
# 4           0.0%                          0.0%           0.0%
#
#              Unnamed: 46
# 0  Form of Incorporation
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
#
# [5 rows x 47 columns]

# %%
bit_dg = "coin_Bitcoin.csv"

# %%
bit_df = pd.read_csv(bit_dg)
bit_df.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
len(bit_df)
# Out:
# 2991

# %%
file_Dog = "coin_Dogecoin.csv"

# %%
doge_df = pd.read_csv(file_Dog)
doge_df.head()
# Out:
#    SNo      Name Symbol                 Date      High       Low      Open  \
# 0    1  Dogecoin   DOGE  2013-12-16 23:59:59  0.000866  0.000150  0.000299
# 1    2  Dogecoin   DOGE  2013-12-17 23:59:59  0.000289  0.000116  0.000207
# 2    3  Dogecoin   DOGE  2013-12-18 23:59:59  0.000362  0.000205  0.000267
# 3    4  Dogecoin   DOGE  2013-12-19 23:59:59  0.001520  0.000328  0.000395
# 4    5  Dogecoin   DOGE  2013-12-20 23:59:59  0.001143  0.000662  0.001143
#
#       Close  Volume     Marketcap
# 0  0.000205     0.0  1.509085e+06
# 1  0.000269     0.0  2.169688e+06
# 2  0.000362     0.0  3.188943e+06
# 3  0.001162     0.0  1.115034e+07
# 4  0.000704     0.0  7.284337e+06

# %%
len(doge_df)
# Out:
# 2760

# %%
bitcoin15to18_df = bit_df[(bit_df['Date'] >"2015-01-01") & (bit_df['Date'] <="2018-12-31")]
bitcoin15to18_df
# Out:
#        SNo     Name Symbol                 Date         High          Low  \
# 612    613  Bitcoin    BTC  2015-01-01 23:59:59   320.434998   314.002991
# 613    614  Bitcoin    BTC  2015-01-02 23:59:59   315.838989   313.565002
# 614    615  Bitcoin    BTC  2015-01-03 23:59:59   315.149994   281.082001
# 615    616  Bitcoin    BTC  2015-01-04 23:59:59   287.230011   257.612000
# 616    617  Bitcoin    BTC  2015-01-05 23:59:59   278.341003   265.084015
# ...    ...      ...    ...                  ...          ...          ...
# 2067  2068  Bitcoin    BTC  2018-12-26 23:59:59  3893.359731  3769.863816
# 2068  2069  Bitcoin    BTC  2018-12-27 23:59:59  3874.416880  3645.448438
# 2069  2070  Bitcoin    BTC  2018-12-28 23:59:59  3956.136094  3642.632103
# 2070  2071  Bitcoin    BTC  2018-12-29 23:59:59  3963.758808  3820.408682
# 2071  2072  Bitcoin    BTC  2018-12-30 23:59:59  3901.909016  3797.219122
#
#              Open        Close        Volume     Marketcap
# 612    320.434998   314.248993  8.036550e+06  4.297536e+09
# 613    314.079010   315.032013  7.860650e+06  4.309551e+09
# 614    314.846008   281.082001  3.305440e+07  3.846270e+09
# 615    281.145996   264.195007  5.562910e+07  3.616321e+09
# 616    265.084015   274.473999  4.396280e+07  3.758098e+09
# ...           ...          ...           ...           ...
# 2067  3819.666691  3857.297520  5.326548e+09  6.729282e+10
# 2068  3854.688573  3654.833539  5.130222e+09  6.376876e+10
# 2069  3653.131929  3923.918594  5.631554e+09  6.847184e+10
# 2070  3932.491809  3820.408682  4.991656e+09  6.667224e+10
# 2071  3822.384835  3865.952577  4.770579e+09  6.747551e+10
#
# [1460 rows x 10 columns]

# %%
dogecoin15to18_df = doge_df[(doge_df['Date'] > "2015-01-01") & (doge_df['Date'] <= "2018-12-31")]
dogecoin15to18_df
# Out:
#        SNo      Name Symbol                 Date      High       Low  \
# 381    382  Dogecoin   DOGE  2015-01-01 23:59:59  0.000186  0.000182
# 382    383  Dogecoin   DOGE  2015-01-02 23:59:59  0.000187  0.000182
# ...        ...       ...           ...           ...
# 1836  0.002402  0.002474  1.747762e+07  2.908681e+08
# 1837  0.002477  0.002364  1.922493e+07  2.779474e+08
# 1838  0.002362  0.002434  1.943989e+07  2.862403e+08
# 1839  0.002439  0.002403  1.698501e+07  2.826581e+08
# 1840  0.002380  0.002367  1.684602e+07  2.784703e+08
#
# [364 rows x 10 columns]

# %%
bitcoin15to18_df_avg = bit_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].mean()
bitcoin15to18_df_avg = pd.DataFrame(bitcoin15to18_df_avg)
bitcoin15to18_df_avg
# Out:
#                High          Low        Open        Close        Volume
# Symbol
# BTC     6893.326038  6486.009539  6700.14624  6711.290443  1.090633e+10

# %%
bitcoin15_avg = bit2015_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].mean()
bitcoin15_avg = pd.DataFrame(bitcoin15_avg)
bitcoin15_avg.insert(0,"Year",[2015])
bitcoin15_avg
# Out:
#         Year        High         Low        Open       Close        Volume
# Symbol
# BTC     2015  277.726789  266.390509  271.726687  272.019003  3.387235e+07

# %%
bitcoin16_avg = bit2016_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].mean()
bitcoin16_avg = pd.DataFrame(bitcoin16_avg)
bitcoin16_avg.insert(0,"Year",[2016])
bitcoin16_avg
# Out:
#         Year        High         Low        Open       Close        Volume
# Symbol
# BTC     2016  573.235312  559.393695  566.063387  567.409529  8.588832e+07

# %%
bitcoin17_avg = bit2017_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].mean()
bitcoin17_avg = pd.DataFrame(bitcoin17_avg)
bitcoin17_avg.insert(0,"Year",[2017])
bitcoin17_avg
# Out:
#         Year         High         Low         Open        Close        Volume
# Symbol
# BTC     2017  4116.575596  3787.13666  3946.119971  3978.148006  2.356072e+09

# %%
bitcoin18_avg = bit2018_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].mean()
bitcoin18_avg = pd.DataFrame(bitcoin18_avg)
bitcoin18_avg.insert(0,"Year",[2018])
bitcoin18_avg
# Out:
#         Year       High          Low         Open        Close        Volume
# Symbol
# BTC     2018  7798.7461  7360.706397  7611.277411  7582.819818  6.067403e+09

# %%
bitcoin1516_avg = bitcoin15_avg.append(bitcoin16_avg)
bitcoin1516_avg
# Out:
#         Year        High         Low        Open       Close        Volume
# Symbol
# BTC     2015  277.726789  266.390509  271.726687  272.019003  3.387235e+07
# BTC     2016  573.235312  559.393695  566.063387  567.409529  8.588832e+07

# %%
bitcoin1718_avg = bitcoin17_avg.append(bitcoin18_avg)
bitcoin1718_avg
# Out:
#         Year         High          Low         Open        Close        Volume
# Symbol
# BTC     2017  4116.575596  3787.136660  3946.119971  3978.148006  2.356072e+09
# BTC     2018  7798.746100  7360.706397  7611.277411  7582.819818  6.067403e+09

# %%
bitcoin1518_avg = bitcoin1516_avg.append(bitcoin1718_avg)
bitcoin1518_avg
# Out:
#         Year         High          Low         Open        Close        Volume
# Symbol
# BTC     2015   277.726789   266.390509   271.726687   272.019003  3.387235e+07
# BTC     2016   573.235312   559.393695   566.063387   567.409529  8.588832e+07
# BTC     2017  4116.575596  3787.136660  3946.119971  3978.148006  2.356072e+09
# BTC     2018  7798.746100  7360.706397  7611.277411  7582.819818  6.067403e+09

# %%
dogecoin15to18_df_avg = doge_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].mean()
dogecoin15to18_df_avg = pd.DataFrame(dogecoin15to18_df_avg)
dogecoin15to18_df_avg
# Out:
#             High       Low      Open     Close        Volume
# Symbol
# DOGE    0.014964  0.012402  0.013669  0.013763  4.326321e+08

# %%
dogecoin15_avg = doge2015_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].mean()
dogecoin15_avg = pd.DataFrame(dogecoin15_avg)
dogecoin15_avg.insert(0,"Year",[2015])
dogecoin15_avg
# Out:
#         Year      High       Low      Open     Close         Volume
# Symbol
# DOGE    2015  0.000147  0.000139  0.000143  0.000143  168748.361693

# %%
dogecoin16_avg = doge2016_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].mean()
dogecoin16_avg = pd.DataFrame(dogecoin16_avg)
dogecoin16_avg.insert(0,"Year",[2016])
dogecoin16_avg
# Out:
#         Year      High       Low      Open     Close         Volume
# Symbol
# DOGE    2016  0.000242  0.000229  0.000235  0.000235  256984.687158

# %%
dogecoin17_avg = doge2017_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].mean()
dogecoin17_avg = pd.DataFrame(dogecoin17_avg)
dogecoin17_avg.insert(0,"Year",[2017])
dogecoin17_avg
# Out:
#         Year      High       Low      Open    Close        Volume
# Symbol
# DOGE    2017  0.001687  0.001451  0.001559  0.00158  1.104967e+07

# %%
dogecoin18_avg = doge2018_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].mean()
dogecoin18_avg = pd.DataFrame(dogecoin18_avg)
dogecoin18_avg.insert(0,"Year",[2018])
dogecoin18_avg
# Out:
#         Year      High      Low      Open     Close        Volume
# Symbol
# DOGE    2018  0.004583  0.00413  0.004374  0.004356  2.173149e+07

# %%
dogecoin1516_avg = dogecoin15_avg.append(dogecoin16_avg)
dogecoin1516_avg
# Out:
#         Year      High       Low      Open     Close         Volume
# Symbol
# DOGE    2015  0.000147  0.000139  0.000143  0.000143  168748.361693
# DOGE    2016  0.000242  0.000229  0.000235  0.000235  256984.687158

# %%
dogecoin1718_avg = dogecoin17_avg.append(dogecoin18_avg)
dogecoin1718_avg
# Out:
#         Year      High       Low      Open     Close        Volume
# Symbol
# DOGE    2017  0.001687  0.001451  0.001559  0.001580  1.104967e+07
# DOGE    2018  0.004583  0.004130  0.004374  0.004356  2.173149e+07

# %%
dogecoin1518_avg = dogecoin1516_avg.append(dogecoin1718_avg)
dogecoin1518_avg
# Out:
#         Year      High       Low      Open     Close        Volume
# Symbol
# DOGE    2015  0.000147  0.000139  0.000143  0.000143  1.687484e+05
# DOGE    2016  0.000242  0.000229  0.000235  0.000235  2.569847e+05
# DOGE    2017  0.001687  0.001451  0.001559  0.001580  1.104967e+07
# DOGE    2018  0.004583  0.004130  0.004374  0.004356  2.173149e+07

# %%
bitcoin15to18_df_max = bit_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].max()
bitcoin15to18_df_max = pd.DataFrame(bitcoin15to18_df_max)
bitcoin15to18_df_max
# Out:
#                 High           Low          Open        Close        Volume
# Symbol
# BTC     64863.098908  62208.964366  63523.754869  63503.45793  3.509679e+11

# %%
bitcoin15_max = bit2015_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].max()
bitcoin15_max = pd.DataFrame(bitcoin15_max)
bitcoin15_max.insert(0,"Year",[2015])
bitcoin15_max
# Out:
#         Year        High         Low        Open       Close       Volume
# Symbol
# BTC     2015  495.562012  456.765015  465.208008  465.321014  263900000.0

# %%
bitcoin16_max = bit2016_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].max()
bitcoin16_max = pd.DataFrame(bitcoin16_max)
bitcoin16_max.insert(0,"Year",[2016])
bitcoin16_max
# Out:
#         Year        High         Low     Open       Close       Volume
# Symbol
# BTC     2016  979.396973  954.502991  975.125  975.921021  363320992.0

# %%
bitcoin17_max = bit2017_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].max()
bitcoin17_max = pd.DataFrame(bitcoin17_max)
bitcoin17_max.insert(0,"Year",[2017])
bitcoin17_max
# Out:
#         Year     High           Low          Open         Close        Volume
# Symbol
# BTC     2017  20089.0  18974.099609  19475.800781  19497.400391  2.219800e+10

# %%
bitcoin18_max = bit2018_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].max()
bitcoin18_max = pd.DataFrame(bitcoin18_max)
bitcoin18_max.insert(0,"Year",[2018])
bitcoin18_max
# Out:
#         Year          High           Low          Open    Close        Volume
# Symbol
# BTC     2018  17712.400391  16764.599609  17527.300781  17527.0  2.384090e+10

# %%
bitcoin1516_max = bitcoin15_max.append(bitcoin16_max)
bitcoin1516_max
# Out:
#         Year        High         Low        Open       Close       Volume
# Symbol
# BTC     2015  495.562012  456.765015  465.208008  465.321014  263900000.0
# BTC     2016  979.396973  954.502991  975.125000  975.921021  363320992.0

# %%
bitcoin1718_max = bitcoin17_max.append(bitcoin18_max)
bitcoin1718_max
# Out:
#         Year          High           Low          Open         Close  \
# Symbol
# BTC     2017  20089.000000  18974.099609  19475.800781  19497.400391
# BTC     2018  17712.400391  16764.599609  17527.300781  17527.000000
#
#               Volume
# Symbol
# BTC     2.219800e+10
# BTC     2.384090e+10

# %%
bitcoin1518_max = bitcoin1516_max.append(bitcoin1718_max)
bitcoin1518_max
# Out:
#         Year          High           Low          Open         Close  \
# Symbol
# BTC     2015    495.562012    456.765015    465.208008    465.321014
# BTC     2016    979.396973    954.502991    975.125000    975.921021
# BTC     2017  20089.000000  18974.099609  19475.800781  19497.400391
# BTC     2018  17712.400391  16764.599609  17527.300781  17527.000000
#
#               Volume
# Symbol
# BTC     2.639000e+08
# BTC     3.633210e+08
# BTC     2.219800e+10
# BTC     2.384090e+10

# %%
dogecoin15to18_df_max = doge_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].max()
dogecoin15to18_df_max = pd.DataFrame(dogecoin15to18_df_max)
dogecoin15to18_df_max
# Out:
#             High       Low      Open     Close        Volume
# Symbol
# DOGE    0.737567  0.608168  0.687801  0.684777  6.941068e+10

# %%
dogecoin15_max = doge2015_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].max()
dogecoin15_max = pd.DataFrame(dogecoin15_max)
dogecoin15_max.insert(0,"Year",[2015])
dogecoin15_max
# Out:
#         Year      High       Low      Open     Close     Volume
# Symbol
# DOGE    2015  0.000247  0.000207  0.000219  0.000219  1504540.0

# %%
dogecoin16_max = doge2016_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].max()
dogecoin16_max = pd.DataFrame(dogecoin16_max)
dogecoin16_max.insert(0,"Year",[2016])
dogecoin16_max
# Out:
#         Year    High       Low      Open     Close     Volume
# Symbol
# DOGE    2016  0.0005  0.000349  0.000455  0.000455  5266350.0

# %%
dogecoin17_max = doge2017_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].max()
dogecoin17_max = pd.DataFrame(dogecoin17_max)
dogecoin17_max.insert(0,"Year",[2017])
dogecoin17_max
# Out:
#         Year      High       Low      Open     Close       Volume
# Symbol
# DOGE    2017  0.010729  0.008582  0.009365  0.009411  178008992.0

# %%
dogecoin18_max = doge2018_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].max()
dogecoin18_max = pd.DataFrame(dogecoin18_max)
dogecoin18_max.insert(0,"Year",[2018])
dogecoin18_max
# Out:
#         Year      High       Low      Open     Close       Volume
# Symbol
# DOGE    2018  0.018773  0.014577  0.017115  0.017088  288184000.0

# %%
dogecoin1516_max = dogecoin15_max.append(dogecoin16_max)
dogecoin1516_max
# Out:
#         Year      High       Low      Open     Close     Volume
# Symbol
# DOGE    2015  0.000247  0.000207  0.000219  0.000219  1504540.0
# DOGE    2016  0.000500  0.000349  0.000455  0.000455  5266350.0

# %%
dogecoin1718_max = dogecoin17_max.append(dogecoin18_max)
dogecoin1718_max
# Out:
#         Year      High       Low      Open     Close       Volume
# Symbol
# DOGE    2017  0.010729  0.008582  0.009365  0.009411  178008992.0
# DOGE    2018  0.018773  0.014577  0.017115  0.017088  288184000.0

# %%
dogecoin1518_max = dogecoin1516_max.append(dogecoin1718_max)
dogecoin1518_max
# Out:
#         Year      High       Low      Open     Close       Volume
# Symbol
# DOGE    2015  0.000247  0.000207  0.000219  0.000219    1504540.0
# DOGE    2016  0.000500  0.000349  0.000455  0.000455    5266350.0
# DOGE    2017  0.010729  0.008582  0.009365  0.009411  178008992.0
# DOGE    2018  0.018773  0.014577  0.017115  0.017088  288184000.0

# %%
bitcoin15to18_df_min = bit_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].min()
bitcoin15to18_df_min = pd.DataFrame(bitcoin15to18_df_min)
bitcoin15to18_df_min
# Out:
#              High        Low       Open   Close  Volume
# Symbol
# BTC     74.561096  65.526001  68.504997  68.431     0.0

# %%
bitcoin15_min = bit2015_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].min()
bitcoin15_min = pd.DataFrame(bitcoin15_min)
bitcoin15_min.insert(0,"Year",[2015])
bitcoin15_min
# Out:
#         Year        High         Low        Open       Close     Volume
# Symbol
# BTC     2015  211.731003  171.509995  176.897003  178.102997  7860650.0

# %%
bitcoin16_min = bit2016_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].min()
bitcoin16_min = pd.DataFrame(bitcoin16_min)
bitcoin16_min.insert(0,"Year",[2016])
bitcoin16_min
# Out:
#         Year        High         Low        Open       Close      Volume
# Symbol
# BTC     2016  374.950012  354.914001  365.072998  364.330994  28514000.0

# %%
bitcoin17_min = bit2017_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].min()
bitcoin17_min = pd.DataFrame(bitcoin17_min)
bitcoin17_min.insert(0,"Year",[2017])
bitcoin17_min
# Out:
#         Year        High         Low        Open       Close      Volume
# Symbol
# BTC     2017  823.307007  755.755981  775.177979  777.757019  60851700.0

# %%
bitcoin18_min = bit2018_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].min()
bitcoin18_min = pd.DataFrame(bitcoin18_min)
bitcoin18_min.insert(0,"Year",[2018])
bitcoin18_min
# Out:
#         Year         High          Low         Open        Close        Volume
# Symbol
# BTC     2018  3275.377827  3191.303562  3236.274773  3236.761645  2.923670e+09

# %%
bitcoin1516_min = bitcoin15_min.append(bitcoin16_min)
bitcoin1516_min
# Out:
#         Year        High         Low        Open       Close      Volume
# Symbol
# BTC     2015  211.731003  171.509995  176.897003  178.102997   7860650.0
# BTC     2016  374.950012  354.914001  365.072998  364.330994  28514000.0

# %%
bitcoin1718_min = bitcoin17_min.append(bitcoin18_min)
bitcoin1718_min
# Out:
#         Year         High          Low         Open        Close        Volume
# Symbol
# BTC     2017   823.307007   755.755981   775.177979   777.757019  6.085170e+07
# BTC     2018  3275.377827  3191.303562  3236.274773  3236.761645  2.923670e+09

# %%
bitcoin1518_min = bitcoin1516_min.append(bitcoin1718_min)
bitcoin1518_min
# Out:
#         Year         High          Low         Open        Close        Volume
# Symbol
# BTC     2015   211.731003   171.509995   176.897003   178.102997  7.860650e+06
# BTC     2016   374.950012   354.914001   365.072998   364.330994  2.851400e+07
# BTC     2017   823.307007   755.755981   775.177979   777.757019  6.085170e+07
# BTC     2018  3275.377827  3191.303562  3236.274773  3236.761645  2.923670e+09

# %%
dogecoin15to18_df_min = doge_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].min()
dogecoin15to18_df_min = pd.DataFrame(dogecoin15to18_df_min)
dogecoin15to18_df_min
# Out:
#             High       Low      Open     Close  Volume
# Symbol
# DOGE    0.000089  0.000085  0.000087  0.000087     0.0

# %%
dogecoin15_min = doge2015_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].min()
dogecoin15_min = pd.DataFrame(dogecoin15_min)
dogecoin15_min.insert(0,"Year",[2015])
dogecoin15_min
# Out:
#         Year      High       Low      Open     Close        Volume
# Symbol
# DOGE    2015  0.000089  0.000085  0.000087  0.000087  16694.800781

# %%
dogecoin16_min = doge2016_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].min()
dogecoin16_min = pd.DataFrame(dogecoin16_min)
dogecoin16_min.insert(0,"Year",[2016])
dogecoin16_min
# Out:
#         Year      High       Low      Open     Close        Volume
# Symbol
# DOGE    2016  0.000138  0.000134  0.000134  0.000135  41477.199219

# %%
dogecoin17_min = doge2017_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].min()
dogecoin17_min = pd.DataFrame(dogecoin17_min)
dogecoin17_min.insert(0,"Year",[2017])
dogecoin17_min
# Out:
#         Year      High       Low      Open     Close   Volume
# Symbol
# DOGE    2017  0.000205  0.000195  0.000197  0.000197  54079.5

# %%
dogecoin18_min = doge2018_df.groupby("Symbol")[["High","Low","Open","Close","Volume"]].min()
dogecoin18_min = pd.DataFrame(dogecoin18_min)
dogecoin18_min.insert(0,"Year",[2018])
dogecoin18_min
# Out:
#         Year      High       Low      Open     Close     Volume
# Symbol
# DOGE    2018  0.002085  0.002006  0.002067  0.002065  2134170.0

# %%
dogecoin1516_min = dogecoin15_min.append(dogecoin16_min)
dogecoin1516_min
# Out:
#         Year      High       Low      Open     Close        Volume
# Symbol
# DOGE    2015  0.000089  0.000085  0.000087  0.000087  16694.800781
# DOGE    2016  0.000138  0.000134  0.000134  0.000135  41477.199219

# %%
dogecoin1718_min = dogecoin17_min.append(dogecoin18_min)
dogecoin1718_min
# Out:
#         Year      High       Low      Open     Close     Volume
# Symbol
# DOGE    2017  0.000205  0.000195  0.000197  0.000197    54079.5
# DOGE    2018  0.002085  0.002006  0.002067  0.002065  2134170.0

# %%
dogecoin1518_min = dogecoin1516_min.append(dogecoin1718_min)
dogecoin1518_min
# Out:
#         Year      High       Low      Open     Close        Volume
# Symbol
# DOGE    2015  0.000089  0.000085  0.000087  0.000087  1.669480e+04
# DOGE    2016  0.000138  0.000134  0.000134  0.000135  4.147720e+04
# DOGE    2017  0.000205  0.000195  0.000197  0.000197  5.407950e+04
# DOGE    2018  0.002085  0.002006  0.002067  0.002065  2.134170e+06

# %%
plt.plot(bitcoin1518_max['Year'], bitcoin1518_max["High"], color='blue')
plt.title('Bitcoin Max High 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Max High', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(bitcoin1518_avg['Year'], bitcoin1518_avg["High"], color='blue')
plt.title('Bitcoin Mean High 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Mean High', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bitcoin1518_min = bitcoin1516_min.append(bitcoin1718_min)
bitcoin1518_min

plt.plot(bitcoin1518_min['Year'], bitcoin1518_min["High"], color='blue')
plt.title('Bitcoin Min High 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Min High', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(bitcoin1518_max['Year'], bitcoin1518_max["Low"], color='blue')
plt.title('Bitcoin Max Low 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Max Low', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(bitcoin1518_avg['Year'], bitcoin1518_avg["Low"], color='blue')
plt.title('Bitcoin Mean Low 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Mean Low', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bitcoin1518_min = bitcoin1516_min.append(bitcoin1718_min)
bitcoin1518_min

plt.plot(bitcoin1518_min['Year'], bitcoin1518_min["Low"], color='blue')
plt.title('Bitcoin Min Low 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Min Low', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(bitcoin1518_max['Year'], bitcoin1518_max["Volume"], color='blue')
plt.title('Bitcoin Max Volume 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Max Volume', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(bitcoin1518_avg['Year'], bitcoin1518_avg["Volume"], color='blue')
plt.title('Bitcoin Mean Volume 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Mean Volume', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
bitcoin1518_min = bitcoin1516_min.append(bitcoin1718_min)
bitcoin1518_min

plt.plot(bitcoin1518_min['Year'], bitcoin1518_min["Volume"], color='blue')
plt.title('Bitcoin Min Volume 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Min Volume', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(dogecoin1518_max['Year'], dogecoin1518_max["High"], color='blue')
plt.title('Dogecoin Max High 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Max High', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(dogecoin1518_avg['Year'], dogecoin1518_avg["High"], color='blue')
plt.title('Dogecoin Mean High 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Mean High', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(dogecoin1518_min['Year'], dogecoin1518_min["High"], color='blue')
plt.title('Dogecoin Min High 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Min High', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(dogecoin1518_max['Year'], dogecoin1518_max["Low"], color='blue')
plt.title('Dogecoin Max Low 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Max Low', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(dogecoin1518_avg['Year'], dogecoin1518_avg["Low"], color='blue')
plt.title('Dogecoin Mean Low 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Mean Low', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(dogecoin1518_min['Year'], dogecoin1518_min["Low"], color='blue')
plt.title('Dogecoin Min Low 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Min Low', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(dogecoin1518_max['Year'], dogecoin1518_max["Volume"], color='blue')
plt.title('Dogecoin Max Volume 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Max Volume', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(dogecoin1518_avg['Year'], dogecoin1518_avg["Volume"], color='blue')
plt.title('Dogecoin Mean Volume 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Mean Volume', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(dogecoin1518_min['Year'], dogecoin1518_min["Volume"], color='blue')
plt.title('Dogecoin Min Volume 2015-2018', fontsize=14)
plt.xlabel('Year', fontsize=14)
plt.ylabel('Min Volume', fontsize=14)
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
